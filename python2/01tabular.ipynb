# %%
import pandas as pd

# %%
oceania = pd.read_csv('../data/gapminder_gdp_oceania.csv', index_col='country')

# %%
oceaniaw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e42b67ed8b8b> in <module>
# ----> 1 oceaniaw
#
# NameError: name 'oceaniaw' is not defined

# %%
oceania
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
oceania.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
americas = pd.read_csv('../data/gapminder_gdp_americas.csv', index_col='country')

# %%
americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
americas.head(3)
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# Argentina     9139.671389     9308.418710    10967.281950     8797.640716
# Bolivia       2753.691490     2961.699694     3326.143191     3413.262690
# Brazil        7807.095818     6950.283021     7957.980824     8131.212843
#
#            gdpPercap_2007
# country
# Argentina    12779.379640
# ...

# %%
americas.tail(3)
# Out:
#               continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# United States  Americas    13990.482080    14847.127120    16173.145860
# Uruguay        Americas     5716.766744     6150.772969     5603.357717
# Venezuela      Americas     7689.799761     9802.466526     8422.974165
#
#                gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# United States    19530.365570    21806.035940    24072.632130    25009.559140
# Uruguay           5444.619620     5703.408898     6504.339663     6920.223051
# Venezuela         9541.474188    10505.259660    13143.950950    11152.410110
#
#                gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# United States    29884.350410    32003.932240    35767.433030    39097.099550
# Uruguay           7452.398969     8137.004775     9230.240708     7727.002004
# Venezuela         9883.584648    10733.926310    10165.495180     8605.047831
#
# ...

# %%
americas.T
# Out:
# country           Argentina      Bolivia       Brazil       Canada  \
# continent          Americas     Americas     Americas     Americas
# gdpPercap_1952  5911.315053  2677.326347  2108.944355  11367.16112
# gdpPercap_1957  6856.856212  2127.686326  2487.365989  12489.95006
# gdpPercap_1962  7133.166023  2180.972546  3336.585802  13462.48555
# gdpPercap_1967  8052.953021  2586.886053  3429.864357  16076.58803
# gdpPercap_1972  9443.038526  2980.331339  4985.711467  18970.57086
# gdpPercap_1977  10079.02674  3548.097832  6660.118654  22090.88306
# gdpPercap_1982  8997.897412  3156.510452  7030.835878  22898.79214
# gdpPercap_1987  9139.671389   2753.69149  7807.095818  26626.51503
# gdpPercap_1992   9308.41871  2961.699694  6950.283021  26342.88426
# gdpPercap_1997  10967.28195  3326.143191  7957.980824  28954.92589
# gdpPercap_2002  8797.640716   3413.26269  8131.212843  33328.96507
# gdpPercap_2007  12779.37964  3822.137084  9065.800825  36319.23501
#
# ...

# %%
americas.T.tail(3)
# Out:
# country           Argentina      Bolivia       Brazil       Canada  \
# gdpPercap_1997  10967.28195  3326.143191  7957.980824  28954.92589
# gdpPercap_2002  8797.640716   3413.26269  8131.212843  33328.96507
# gdpPercap_2007  12779.37964  3822.137084  9065.800825  36319.23501
#
# country               Chile     Colombia   Costa Rica         Cuba  \
# gdpPercap_1997  10118.05318  6117.361746  6677.045314  5431.990415
# gdpPercap_2002  10778.78385  5755.259962  7723.447195  6340.646683
# gdpPercap_2007  13171.63885  7006.580419   9645.06142  8948.102923
#
# country        Dominican Republic      Ecuador  ...       Mexico    Nicaragua  \
# gdpPercap_1997        3614.101285  7429.455877  ...   9767.29753  2253.023004
# gdpPercap_2002        4563.808154  5773.044512  ...  10742.44053  2474.548819
# gdpPercap_2007        6025.374752  6873.262326  ...  11977.57496  2749.320965
#
# country              Panama     Paraguay         Peru  Puerto Rico  \
# ...

# %%
# help(americas.to_csv)

# %% [raw]
# # Let's write to a csv with `pd.to_csv`

# %%
# Transpose americas data and write to processed.csv:
processed = americas.T.to_csv("../data/processed.csv")

# %%
processed

# %%
type(processed)
# Out:
# NoneType

# %%
x = max([1,2,3])

# %%
x
# Out:
# 3

# %%
processed = pd.read_csv("../data/processed.csv")

# %%
proccessed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-79543e9dcf2e> in <module>
# ----> 1 proccessed
#
# NameError: name 'proccessed' is not defined

# %%
processed
# Out:
#         Unnamed: 0    Argentina      Bolivia       Brazil       Canada  \
# 0        continent     Americas     Americas     Americas     Americas
# 1   gdpPercap_1952  5911.315053  2677.326347  2108.944355  11367.16112
# 2   gdpPercap_1957  6856.856212  2127.686326  2487.365989  12489.95006
# 3   gdpPercap_1962  7133.166023  2180.972546  3336.585802  13462.48555
# 4   gdpPercap_1967  8052.953021  2586.886053  3429.864357  16076.58803
# 5   gdpPercap_1972  9443.038526  2980.331339  4985.711467  18970.57086
# 6   gdpPercap_1977  10079.02674  3548.097832  6660.118654  22090.88306
# 7   gdpPercap_1982  8997.897412  3156.510452  7030.835878  22898.79214
# 8   gdpPercap_1987  9139.671389   2753.69149  7807.095818  26626.51503
# 9   gdpPercap_1992   9308.41871  2961.699694  6950.283021  26342.88426
# 10  gdpPercap_1997  10967.28195  3326.143191  7957.980824  28954.92589
# 11  gdpPercap_2002  8797.640716   3413.26269  8131.212843  33328.96507
# ...

# %%
americas.iloc[0,0]
# Out:
# 'Americas'

# %%
americas.iloc[1,2]
# Out:
# 2127.686326

# %%
americas.loc["Canada","gdpPercap_1972"]
# Out:
# 18970.57086

# %%
# americas

# %% [markdown]
# ## slices

# %%
americas.loc[:, "gdpPercap_1952"]
# Out:
# country
# Argentina               5911.315053
# Bolivia                 2677.326347
# Brazil                  2108.944355
# Canada                 11367.161120
# Chile                   3939.978789
# Colombia                2144.115096
# Costa Rica              2627.009471
# Cuba                    5586.538780
# Dominican Republic      1397.717137
# Ecuador                 3522.110717
# El Salvador             3048.302900
# Guatemala               2428.237769
# Haiti                   1840.366939
# Honduras                2194.926204
# Jamaica                 2898.530881
# Mexico                  3478.125529
# Nicaragua               3112.363948
# Panama                  2480.380334
# Paraguay                1952.308701
# Peru                    3758.523437
# Puerto Rico             3081.959785
# Trinidad and Tobago     3023.271928
# United States          13990.482080
# Uruguay                 5716.766744
# Venezuela               7689.799761
# Name: gdpPercap_1952, dtype: float64

# %%
name = 'Alan Crosswell'
name[4:]
# Out:
# ' Crosswell'

# %%
name[:5]
# Out:
# 'Alan '

# %%
name[3:7]
# Out:
# 'n Cr'

# %%
americas.loc['Cuba':'Peru', 'gdpPercap_1962':'gdpPercap_1972']
# Out:
#                     gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Cuba                   5180.755910     5690.268015     5305.445256
# Dominican Republic     1662.137359     1653.723003     2189.874499
# Ecuador                4086.114078     4579.074215     5280.994710
# El Salvador            3776.803627     4358.595393     4520.246008
# Guatemala              2750.364446     3242.531147     4031.408271
# Haiti                  1796.589032     1452.057666     1654.456946
# Honduras               2291.156835     2538.269358     2529.842345
# Jamaica                5246.107524     6124.703451     7433.889293
# Mexico                 4581.609385     5754.733883     6809.406690
# Nicaragua              3634.364406     4643.393534     4688.593267
# Panama                 3536.540301     4421.009084     5364.249663
# Paraguay               2148.027146     2299.376311     2523.337977
# Peru                   4957.037982     5788.093330     5937.827283

# %%
americas.loc['Cuba':'Peru', 'gdpPercap_1962':'gdpPercap_1972'].max()
# Out:
# gdpPercap_1962    5246.107524
# gdpPercap_1967    6124.703451
# gdpPercap_1972    7433.889293
# dtype: float64

# %%
europe = pd.read_csv("../data/gapminder_gdp_europe.csv", index_col="country")

# %%
subset = europe.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']

# %%
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
subset > 10000
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %% [markdown]
# # boolean mask!

# %%
mask = subset > 10000

# %%
type(mask)
# Out:
# pandas.core.frame.DataFrame

# %%
mask
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
subset[mask]
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                   NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN
# Netherlands     12790.84956     15363.25136     18794.74567
# Norway          13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN

# %% [markdown]
# # `NaN` - Not a Number

# %%
subset[mask].mean()
# Out:
# gdpPercap_1962    13120.625535
# gdpPercap_1967    13915.843047
# gdpPercap_1972    16676.358320
# dtype: float64

# %%
mask
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
mask.mean()
# Out:
# gdpPercap_1962    0.4
# gdpPercap_1967    0.6
# gdpPercap_1972    0.6
# dtype: float64

# %% [markdown]
# # What was the Per Capita GDP of Serbia in 2007?

# %%
europe.loc['Serbia']
# Out:
# gdpPercap_1952     3581.459448
# gdpPercap_1957     4981.090891
# gdpPercap_1962     6289.629157
# gdpPercap_1967     7991.707066
# gdpPercap_1972    10522.067490
# gdpPercap_1977    12980.669560
# gdpPercap_1982    15181.092700
# gdpPercap_1987    15870.878510
# gdpPercap_1992     9325.068238
# gdpPercap_1997     7914.320304
# gdpPercap_2002     7236.075251
# gdpPercap_2007     9786.534714
# Name: Serbia, dtype: float64

# %%
europe.loc['Serbia','gdpPercap_2007']
# Out:
# 9786.534714

# %%
first = pd.read_csv('../data/gapminder_all.csv', index_col='country')
second = first[first['continent'] == 'Americas']
third = second.drop('Puerto Rico')
fourth = third.drop('continent', axis = 1)
fourth.to_csv('../data/result.csv')

# %%
fourth.T
# Out:
# country            Argentina       Bolivia        Brazil        Canada  \
# gdpPercap_1952  5.911315e+03  2.677326e+03  2.108944e+03  1.136716e+04
# gdpPercap_1957  6.856856e+03  2.127686e+03  2.487366e+03  1.248995e+04
# gdpPercap_1962  7.133166e+03  2.180973e+03  3.336586e+03  1.346249e+04
# gdpPercap_1967  8.052953e+03  2.586886e+03  3.429864e+03  1.607659e+04
# gdpPercap_1972  9.443039e+03  2.980331e+03  4.985711e+03  1.897057e+04
# gdpPercap_1977  1.007903e+04  3.548098e+03  6.660119e+03  2.209088e+04
# gdpPercap_1982  8.997897e+03  3.156510e+03  7.030836e+03  2.289879e+04
# gdpPercap_1987  9.139671e+03  2.753691e+03  7.807096e+03  2.662652e+04
# gdpPercap_1992  9.308419e+03  2.961700e+03  6.950283e+03  2.634288e+04
# gdpPercap_1997  1.096728e+04  3.326143e+03  7.957981e+03  2.895493e+04
# gdpPercap_2002  8.797641e+03  3.413263e+03  8.131213e+03  3.332897e+04
# gdpPercap_2007  1.277938e+04  3.822137e+03  9.065801e+03  3.631924e+04
# ...

# %%
americas.T
# Out:
# country           Argentina      Bolivia       Brazil       Canada  \
# continent          Americas     Americas     Americas     Americas
# gdpPercap_1952  5911.315053  2677.326347  2108.944355  11367.16112
# gdpPercap_1957  6856.856212  2127.686326  2487.365989  12489.95006
# gdpPercap_1962  7133.166023  2180.972546  3336.585802  13462.48555
# gdpPercap_1967  8052.953021  2586.886053  3429.864357  16076.58803
# gdpPercap_1972  9443.038526  2980.331339  4985.711467  18970.57086
# gdpPercap_1977  10079.02674  3548.097832  6660.118654  22090.88306
# gdpPercap_1982  8997.897412  3156.510452  7030.835878  22898.79214
# gdpPercap_1987  9139.671389   2753.69149  7807.095818  26626.51503
# gdpPercap_1992   9308.41871  2961.699694  6950.283021  26342.88426
# gdpPercap_1997  10967.28195  3326.143191  7957.980824  28954.92589
# gdpPercap_2002  8797.640716   3413.26269  8131.212843  33328.96507
# gdpPercap_2007  12779.37964  3822.137084  9065.800825  36319.23501
#
# ...

# %%
my_string = "Hello, world"

# %%
type(my_string)
# Out:
# str

# %%
str.uppercase()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d914e317dcb9> in <module>
# ----> 1 str.uppercase()
#
# AttributeError: type object 'str' has no attribute 'uppercase'

# %%
my_string.upper()
# Out:
# 'HELLO, WORLD'

# %%
my_string.uppercase()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-f5c1b49ee972> in <module>
# ----> 1 my_string.uppercase()
#
# AttributeError: 'str' object has no attribute 'uppercase'

# %%
dir(my_string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
my_string.lower().capitalize()
# Out:
# 'Hello, world'

# %%
help(my_string.title)
# Out:
# Help on built-in function title:
#
# title() method of builtins.str instance
#     Return a version of the string where each word is titlecased.
#
#     More specifically, words start with uppercased characters and all remaining
#     cased characters have lower case.

# %%
my_string.title()
# Out:
# 'Hello, World'

# %% [markdown]
# ## dir() and help() to find out what methods are available.

# %%
dir(europe)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...
